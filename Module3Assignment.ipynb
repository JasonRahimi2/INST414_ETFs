# %%
#Importing libraries
import pandas as pd
import scipy.spatial.distance

# %%
#Reading CSV file and developing a Dataframe
large_cap_etfs = pd.read_csv("etfdb_large_cap.csv")
large_cap_etfs_df = pd.DataFrame(large_cap_etfs)
print(large_cap_etfs_df.columns)
# Out:
# Index(['Symbol', 'ETF Name', 'Asset Class', 'Total Assets ',
#        'YTD Price Change', 'Avg. Daily Volume', 'Previous Closing Price',
#        '1-Day Change', 'Inverse', 'Leveraged', '1 Week', '1 Month', '1 Year',
#        '3 Year', '5 Year', 'YTD FF', '1 Week FF', '4 Week FF', '1 Year FF',
#        '3 Year FF', '5 Year FF', 'ETF Database Category', 'Inception', 'ER',
#        'Commission Free', 'Annual Dividend Rate', 'Dividend Date', 'Dividend',
#        'Annual Dividend Yield %', 'P/E Ratio', 'Beta', '# of Holdings',
#        '% In Top 10', 'ST Cap Gain Rate', 'LT Cap Gain Rate', 'Tax Form',
#        'Lower Bollinger', 'Upper Bollinger', 'Support 1', 'Resistance 1',
#        'RSI', 'Liquidity Rating', 'Expenses Rating', 'Returns Rating',
#        'Volatility Rating', 'Dividend Rating', 'Concentration Rating',
#        'ESG Score', 'ESG Score Peer Percentile (%)',
#        'ESG Score Global Percentile (%)',
#        'Carbon Intensity (Tons of CO2e / $M Sales)',
#        'SRI Exclusion Criteria (%)', 'Sustainable Impact Solutions (%)'],
#       dtype='object')

# %%
#Developing a new Dataframe and renaming columns
new_df = large_cap_etfs_df[['Symbol', 'ETF Name', 'Total Assets ', 'YTD Price Change', 'Avg. Daily Volume', 'ER', 'Annual Dividend Yield %',
                            'Beta', '# of Holdings']].copy()
new_df = new_df.rename(columns={'ER': 'Expense Ratio', 'YTD Price Change': 'YTD Price Change %'})
new_df
# Out:
#     Symbol                               ETF Name     Total Assets   \
# 0      SPY                 SPDR S&P 500 ETF Trust  $533,453,000,000
# 1      IVV               iShares Core S&P 500 ETF  $439,738,000,000
# 2      VOO                   Vanguard S&P 500 ETF  $432,244,000,000
# 3      VTI        Vanguard Total Stock Market ETF  $388,015,000,000
# 4      QQQ             Invesco QQQ Trust Series I  $257,679,000,000
# ..     ...                                    ...               ...
# 916   TSLH     Innovator Hedged TSLA Strategy ETF          $926,400
# 917    SZK  ProShares UltraShort Consumer Staples          $829,891
# 918   CETF         DriveWealth NYSE 100 Index ETF          $775,135
# 919    EFU         ProShares UltraShort MSCI EAFE          $658,315
# 920   BITW           Bitwise 10 Crypto Index Fund                $0
#
#     YTD Price Change % Avg. Daily Volume Expense Ratio  \
# 0               10.21%        75,349,808         0.09%
# 1                9.84%         5,706,798         0.03%
# 2               10.20%         5,162,791         0.03%
# 3                9.66%         3,398,947         0.03%
# 4                9.02%        44,842,856         0.20%
# ..                 ...               ...           ...
# 916             -8.64%             1,423         0.79%
# 917             -9.38%             2,113         0.95%
# 918              3.81%               110         0.85%
# 919            -10.42%             5,860         0.95%
# 920                NaN               NaN         2.50%
#
#     Annual Dividend Yield %  Beta  # of Holdings
# 0                     1.29%  1.00          504.0
# 1                     1.32%  1.00          504.0
# 2                     1.32%  1.00          505.0
# 3                     1.32%  1.02         3686.0
# 4                     0.59%  1.11          102.0
# ..                      ...   ...            ...
# 916                   4.03% -0.15            3.0
# 917                   5.52% -1.65            1.0
# 918                   0.00%   NaN          102.0
# 919                   5.82% -1.64            1.0
# 920                     NaN   NaN            0.0
#
# [921 rows x 9 columns]

# %%
#Dropping NA values
new_df = new_df.dropna()
new_df
# Out:
#     Symbol                               ETF Name     Total Assets   \
# 0      SPY                 SPDR S&P 500 ETF Trust  $533,453,000,000
# 1      IVV               iShares Core S&P 500 ETF  $439,738,000,000
# 2      VOO                   Vanguard S&P 500 ETF  $432,244,000,000
# 3      VTI        Vanguard Total Stock Market ETF  $388,015,000,000
# 4      QQQ             Invesco QQQ Trust Series I  $257,679,000,000
# ..     ...                                    ...               ...
# 914    RXD       ProShares UltraShort Health Care        $1,055,960
# 915    SMN         ProShares UltraShort Materials          $962,115
# 916   TSLH     Innovator Hedged TSLA Strategy ETF          $926,400
# 917    SZK  ProShares UltraShort Consumer Staples          $829,891
# 919    EFU         ProShares UltraShort MSCI EAFE          $658,315
#
#     YTD Price Change % Avg. Daily Volume Expense Ratio  \
# 0               10.21%        75,349,808         0.09%
# 1                9.84%         5,706,798         0.03%
# 2               10.20%         5,162,791         0.03%
# 3                9.66%         3,398,947         0.03%
# 4                9.02%        44,842,856         0.20%
# ..                 ...               ...           ...
# 914            -11.02%             3,042         0.95%
# 915            -12.75%             5,539         0.95%
# 916             -8.64%             1,423         0.79%
# 917             -9.38%             2,113         0.95%
# 919            -10.42%             5,860         0.95%
#
#     Annual Dividend Yield %  Beta  # of Holdings
# 0                     1.29%  1.00          504.0
# 1                     1.32%  1.00          504.0
# 2                     1.32%  1.00          505.0
# 3                     1.32%  1.02         3686.0
# 4                     0.59%  1.11          102.0
# ..                      ...   ...            ...
# 914                   4.29% -1.25            1.0
# 915                   5.49% -2.11            1.0
# 916                   4.03% -0.15            3.0
# 917                   5.52% -1.65            1.0
# 919                   5.82% -1.64            1.0
#
# [886 rows x 9 columns]

# %%
#Data cleaning
new_df.loc[:, ('Total Assets ')] = new_df['Total Assets '].str.replace('$', '')
new_df.loc[:, ('Total Assets ')] = new_df['Total Assets '].str.replace(',', '')
new_df.loc[:, ('YTD Price Change %')] = new_df['YTD Price Change %'].str.replace('%', '')
new_df.loc[:, ('Avg. Daily Volume')] = new_df['Avg. Daily Volume'].str.replace(',', '')
new_df.loc[:, ('Expense Ratio')] = new_df['Expense Ratio'].str.replace('%', '')
new_df.loc[:, ('Annual Dividend Yield %')] = new_df['Annual Dividend Yield %'].str.replace('%', '')
dict_type = {'Total Assets ': int, 'YTD Price Change %': float, 'Avg. Daily Volume': int, 'Expense Ratio': float,
          'Annual Dividend Yield %': float}
new_df = new_df.astype(dict_type)
new_df.head(50)
# Out:
#    Symbol                                           ETF Name  Total Assets   \
# 0     SPY                             SPDR S&P 500 ETF Trust   533453000000
# 1     IVV                           iShares Core S&P 500 ETF   439738000000
# 2     VOO                               Vanguard S&P 500 ETF   432244000000
# 3     VTI                    Vanguard Total Stock Market ETF   388015000000
# 4     QQQ                         Invesco QQQ Trust Series I   257679000000
# 5     VEA                Vanguard FTSE Developed Markets ETF   131049000000
# 6     VUG                                Vanguard Growth ETF   119459000000
# 7    IEFA                         iShares Core MSCI EAFE ETF   114988000000
# 8     VTV                                 Vanguard Value ETF   114682000000
# 9     IWF                    iShares Russell 1000 Growth ETF    89866200000
# 10    VIG                 Vanguard Dividend Appreciation ETF    78560500000
# 11   IEMG             iShares Core MSCI Emerging Markets ETF    76114700000
# 12    VWO                 Vanguard FTSE Emerging Markets ETF    75863500000
# 13   VXUS             Vanguard Total International Stock ETF    68410600000
# 14    VGT                Vanguard Information Technology ETF    66136700000
# 15    XLK                 Technology Select Sector SPDR Fund    64955000000
# 16    IWD                     iShares Russell 1000 Value ETF    55517500000
# 17   SCHD                      Schwab US Dividend Equity ETF    55171800000
# 18   ITOT       iShares Core S&P Total U.S. Stock Market ETF    54123100000
# 19    VYM             Vanguard High Dividend Yield Index ETF    53820800000
# 20    EFA                              iShares MSCI EAFE ETF    53372600000
# 21    IVW                         iShares S&P 500 Growth ETF    44178900000
# 22   QUAL                iShares MSCI USA Quality Factor ETF    42565000000
# 23    XLV                Health Care Select Sector SPDR Fund    40900400000
# 24   SCHX                          Schwab U.S. Large-Cap ETF    39905100000
# 25    VEU           Vanguard FTSE All-World ex-US Index Fund    38800900000
# 26    XLE                     Energy Select Sector SPDR Fund    38438800000
# 27    XLF                  Financial Select Sector SPDR Fund    37755600000
# 28   SCHF                    Schwab International Equity ETF    36532900000
# 29   IXUS    iShares Core MSCI Total International Stock ETF    36213400000
# 30     VT                     Vanguard Total World Stock ETF    35632700000
# 31    IWB                           iShares Russell 1000 ETF    35307300000
# 32     VV                             Vanguard Large Cap ETF    34458500000
# 33   JEPI  JPMorgan Equity Premium Income Fund JPMorgan E...    33355800000
# 34    IVE                          iShares S&P 500 Value ETF    33321600000
# 35   SPLG                         SPDR Portfolio S&P 500 ETF    33084100000
# 36   SCHB                       Schwab U.S. Broad Market ETF    27688100000
# 37   SCHG                   Schwab U.S. Large-Cap Growth ETF    26866900000
# 38   DGRO                   iShares Core Dividend Growth ETF    26858300000
# 39   SPYG                  SPDR Portfolio S&P 500 Growth ETF    24888300000
# 40   QQQM                             Invesco NASDAQ 100 ETF    22856800000
# 41   TQQQ                             ProShares UltraPro QQQ    22090300000
# 42   SPYV                   SPDR Portfolio S&P 500 Value ETF    21002100000
# 43    XLY     Consumer Discretionary Select Sector SPDR Fund    19919900000
# 44   SPDW           SPDR Portfolio Developed World ex-US ETF    19791900000
# 45   VONG                   Vanguard Russell 1000 Growth ETF    19548700000
# 46    VGK                           Vanguard FTSE Europe ETF    19505100000
# 47   ACWI                              iShares MSCI ACWI ETF    19498500000
# 48    EEM                  iShares MSCI Emerging Markets ETF    18160000000
# 49    SMH                           VanEck Semiconductor ETF    18151500000
#
#     YTD Price Change %  Avg. Daily Volume  Expense Ratio  \
# 0                10.21           75349808           0.09
# 1                 9.84            5706798           0.03
# 2                10.20            5162791           0.03
# 3                 9.66            3398947           0.03
# 4                 9.02           44842856           0.20
# 5                 5.21           11274696           0.05
# 6                11.43             991498           0.04
# 7                 5.43            8383079           0.07
# 8                 8.52            2420637           0.04
# 9                11.72            1400402           0.19
# 10                7.38            1137245           0.06
# 11                2.12           11058809           0.09
# 12                1.98           10452931           0.08
# 13                4.37            3525850           0.07
# 14                9.24             498160           0.10
# 15                9.20            6860071           0.09
# 16                7.10            2290587           0.19
# 17                5.73            3650415           0.06
# 18                9.27            1420995           0.03
# 19                7.82            1199179           0.06
# 20                5.92           14971132           0.35
# 21               13.13            3742360           0.18
# 22               12.44            1852887           0.15
# 23                7.17            8182156           0.09
# 24               10.24            1918458           0.03
# 25                4.82            2451247           0.08
# 26               11.34           16312832           0.09
# 27               11.85           44511344           0.09
# 28                5.55            3801953           0.06
# 29                4.51            1798666           0.07
# 30                7.65            2008005           0.07
# 31                9.56             780189           0.15
# 32               10.24             278600           0.04
# 33                5.92            3594874           0.35
# 34                6.19            1062244           0.18
# 35               10.24            8273280           0.02
# 36                9.62             877185           0.03
# 37               12.39            1479394           0.04
# 38                7.00            1617206           0.08
# 39               13.24            1997929           0.04
# 40                9.04            1824903           0.15
# 41               23.71           73894360           0.88
# 42                6.75            2793495           0.04
# 43                3.31            4702791           0.09
# 44                5.26            3286873           0.03
# 45               11.90             902434           0.08
# 46                4.54            2281085           0.11
# 47                8.07            4484693           0.32
# 48                2.34           29889566           0.70
# 49               29.42            8886574           0.35
#
#     Annual Dividend Yield %  Beta  # of Holdings
# 0                      1.29  1.00          504.0
# 1                      1.32  1.00          504.0
# 2                      1.32  1.00          505.0
# 3                      1.32  1.02         3686.0
# 4                      0.59  1.11          102.0
# 5                      3.28  0.89         4017.0
# 6                      0.53  1.11          209.0
# 7                      3.04  0.87         2831.0
# 8                      2.40  0.89          352.0
# 9                      0.65  1.08          442.0
# 10                     1.76  0.85          317.0
# 11                     2.83  0.75         2918.0
# 12                     3.48  0.69         4716.0
# 13                     3.29  0.85         8469.0
# 14                     0.59  1.16          317.0
# 15                     0.71  1.14           67.0
# 16                     1.89  0.95          848.0
# 17                     3.37  0.88          102.0
# 18                     1.35  1.02         2492.0
# 19                     2.88  0.84          452.0
# 20                     2.81  0.86          771.0
# 21                     0.91  1.05          228.0
# 22                     1.10  1.03          127.0
# 23                     1.51  0.70           65.0
# 24                     1.30  1.01          749.0
# 25                     3.35  0.82         3784.0
# 26                     3.17  1.36           25.0
# 27                     1.54  1.07           73.0
# 28                     2.85  0.87         1505.0
# 29                     2.99  0.84         4357.0
# 30                     2.07  0.94         9739.0
# 31                     1.20  1.01         1006.0
# 32                     1.29  1.01          531.0
# 33                     7.59  0.62          119.0
# 34                     1.56  0.94          443.0
# 35                     1.35  1.00          506.0
# 36                     1.30  1.03         2410.0
# 37                     0.43  1.10          247.0
# 38                     2.29  0.89          421.0
# 39                     0.92  1.05          229.0
# 40                     0.65  1.18          103.0
# 41                     1.13  3.45          118.0
# 42                     1.81  0.94          444.0
# 43                     0.73  1.18           54.0
# 44                     2.61  0.89         2444.0
# 45                     0.66  1.08          444.0
# 46                     3.26  0.95         1296.0
# 47                     1.74  0.93         2335.0
# 48                     2.58  0.74         1230.0
# 49                     0.46  1.35           25.0

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 886 entries, 0 to 919
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Symbol                   886 non-null    object
#  1   ETF Name                 886 non-null    object
#  2   Total Assets             886 non-null    int64
#  3   YTD Price Change %       886 non-null    float64
#  4   Avg. Daily Volume        886 non-null    int64
#  5   Expense Ratio            886 non-null    float64
#  6   Annual Dividend Yield %  886 non-null    float64
#  7   Beta                     886 non-null    float64
#  8   # of Holdings            886 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 69.2+ KB

# %%
#Developing a new Dataframe
float_df = pd.DataFrame()
float_df = new_df[['Total Assets ', 'YTD Price Change %', 'Avg. Daily Volume', 'Expense Ratio',
                  'Annual Dividend Yield %', 'Beta', '# of Holdings']].copy()

# %%
#Normalizing values with min-max normalization
df_range = (float_df.max(axis=0) - float_df.min(axis=0))
df_min_max = (float_df - float_df.min(axis=0))/ df_range
df_min_max
# Out:
#      Total Assets   YTD Price Change %  Avg. Daily Volume  Expense Ratio  \
# 0     1.000000e+00            0.262236           0.555152       0.031690
# 1     8.243236e-01            0.260686           0.042045       0.010563
# 2     8.102755e-01            0.262194           0.038037       0.010563
# 3     7.273646e-01            0.259931           0.025041       0.010563
# 4     4.830391e-01            0.257249           0.330387       0.070423
# ..             ...                 ...                ...            ...
# 914   7.454180e-07            0.173274           0.000021       0.334507
# 915   5.694979e-07            0.166024           0.000040       0.334507
# 916   5.025472e-07            0.183247           0.000010       0.278169
# 917   3.216332e-07            0.180146           0.000015       0.334507
# 919   0.000000e+00            0.175788           0.000042       0.334507
#
#      Annual Dividend Yield %      Beta  # of Holdings
# 0                   0.013197  0.642932       0.051751
# 1                   0.013504  0.642932       0.051751
# 2                   0.013504  0.642932       0.051853
# 3                   0.013504  0.645026       0.378478
# 4                   0.006036  0.654450       0.010473
# ..                       ...       ...            ...
# 914                 0.043887  0.407330       0.000103
# 915                 0.056164  0.317277       0.000103
# 916                 0.041228  0.522513       0.000308
# 917                 0.056471  0.365445       0.000103
# 919                 0.059540  0.366492       0.000103
#
# [886 rows x 7 columns]

# %%
df_min_max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 886 entries, 0 to 919
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Total Assets             886 non-null    float64
#  1   YTD Price Change %       886 non-null    float64
#  2   Avg. Daily Volume        886 non-null    float64
#  3   Expense Ratio            886 non-null    float64
#  4   Annual Dividend Yield %  886 non-null    float64
#  5   Beta                     886 non-null    float64
#  6   # of Holdings            886 non-null    float64
# dtypes: float64(7)
# memory usage: 55.4 KB

# %%
df_min_max.max(axis=0)
# Out:
# Total Assets               1.0
# YTD Price Change %         1.0
# Avg. Daily Volume          1.0
# Expense Ratio              1.0
# Annual Dividend Yield %    1.0
# Beta                       1.0
# # of Holdings              1.0
# dtype: float64

# %%
#Developing function to find euclidean distance 
def distance(etf):
    etf_distance = pd.DataFrame()
    distances = scipy.spatial.distance.cdist(df_min_max, [df_min_max.iloc[etf]], metric='euclidean')[:, 0]
    
    etf_distance['Symbol'] = new_df['Symbol'].copy()
    etf_distance['ETF Name'] = new_df['ETF Name'].copy()
    etf_distance['Distances'] = distances
        
    etf_distance = etf_distance.sort_values(by='Distances')
    return etf_distance.head(11)

# %%
#Finding euclidean distance for SPY
SPY = distance(0)
SPY
# Out:
#    Symbol                             ETF Name  Distances
# 0     SPY               SPDR S&P 500 ETF Trust   0.000000
# 1     IVV             iShares Core S&P 500 ETF   0.542761
# 2     VOO                 Vanguard S&P 500 ETF   0.551226
# 4     QQQ           Invesco QQQ Trust Series I   0.566728
# 3     VTI      Vanguard Total Stock Market ETF   0.680114
# 6     VUG                  Vanguard Growth ETF   0.950717
# 8     VTV                   Vanguard Value ETF   0.951753
# 7    IEFA           iShares Core MSCI EAFE ETF   0.957516
# 27    XLF    Financial Select Sector SPDR Fund   0.957679
# 5     VEA  Vanguard FTSE Developed Markets ETF   0.960828
# 9     IWF      iShares Russell 1000 Growth ETF   0.994855

# %%
#Finding euclidean distance for XLK
XLK = distance(15)
XLK
# Out:
#    Symbol                                ETF Name  Distances
# 15    XLK      Technology Select Sector SPDR Fund   0.000000
# 17   SCHD           Schwab US Dividend Equity ETF   0.052088
# 14    VGT     Vanguard Information Technology ETF   0.053658
# 21    IVW              iShares S&P 500 Growth ETF   0.060714
# 22   QUAL     iShares MSCI USA Quality Factor ETF   0.062768
# 10    VIG      Vanguard Dividend Appreciation ETF   0.065532
# 23    XLV     Health Care Select Sector SPDR Fund   0.066260
# 19    VYM  Vanguard High Dividend Yield Index ETF   0.073230
# 35   SPLG              SPDR Portfolio S&P 500 ETF   0.081203
# 9     IWF         iShares Russell 1000 Growth ETF   0.081686
# 37   SCHG        Schwab U.S. Large-Cap Growth ETF   0.086749

# %%
#Finding euclidean distance for VYM
VYM = distance(19)
VYM
# Out:
#    Symbol                                ETF Name  Distances
# 19    VYM  Vanguard High Dividend Yield Index ETF   0.000000
# 17   SCHD           Schwab US Dividend Equity ETF   0.041755
# 32     VV                  Vanguard Large Cap ETF   0.046509
# 24   SCHX               Schwab U.S. Large-Cap ETF   0.049307
# 10    VIG      Vanguard Dividend Appreciation ETF   0.049789
# 14    VGT     Vanguard Information Technology ETF   0.051548
# 38   DGRO        iShares Core Dividend Growth ETF   0.051957
# 34    IVE               iShares S&P 500 Value ETF   0.060021
# 22   QUAL     iShares MSCI USA Quality Factor ETF   0.060733
# 16    IWD          iShares Russell 1000 Value ETF   0.063779
# 42   SPYV        SPDR Portfolio S&P 500 Value ETF   0.064982

# %%
#Concatenating SPY, XLK, and VYM Dataframes
summary_df = pd.concat([SPY, XLK, VYM])
summary_df
# Out:
#    Symbol                                ETF Name  Distances
# 0     SPY                  SPDR S&P 500 ETF Trust   0.000000
# 1     IVV                iShares Core S&P 500 ETF   0.542761
# 2     VOO                    Vanguard S&P 500 ETF   0.551226
# 4     QQQ              Invesco QQQ Trust Series I   0.566728
# 3     VTI         Vanguard Total Stock Market ETF   0.680114
# 6     VUG                     Vanguard Growth ETF   0.950717
# 8     VTV                      Vanguard Value ETF   0.951753
# 7    IEFA              iShares Core MSCI EAFE ETF   0.957516
# 27    XLF       Financial Select Sector SPDR Fund   0.957679
# 5     VEA     Vanguard FTSE Developed Markets ETF   0.960828
# 9     IWF         iShares Russell 1000 Growth ETF   0.994855
# 15    XLK      Technology Select Sector SPDR Fund   0.000000
# 17   SCHD           Schwab US Dividend Equity ETF   0.052088
# 14    VGT     Vanguard Information Technology ETF   0.053658
# 21    IVW              iShares S&P 500 Growth ETF   0.060714
# 22   QUAL     iShares MSCI USA Quality Factor ETF   0.062768
# 10    VIG      Vanguard Dividend Appreciation ETF   0.065532
# 23    XLV     Health Care Select Sector SPDR Fund   0.066260
# 19    VYM  Vanguard High Dividend Yield Index ETF   0.073230
# 35   SPLG              SPDR Portfolio S&P 500 ETF   0.081203
# 9     IWF         iShares Russell 1000 Growth ETF   0.081686
# 37   SCHG        Schwab U.S. Large-Cap Growth ETF   0.086749
# 19    VYM  Vanguard High Dividend Yield Index ETF   0.000000
# 17   SCHD           Schwab US Dividend Equity ETF   0.041755
# 32     VV                  Vanguard Large Cap ETF   0.046509
# 24   SCHX               Schwab U.S. Large-Cap ETF   0.049307
# 10    VIG      Vanguard Dividend Appreciation ETF   0.049789
# 14    VGT     Vanguard Information Technology ETF   0.051548
# 38   DGRO        iShares Core Dividend Growth ETF   0.051957
# 34    IVE               iShares S&P 500 Value ETF   0.060021
# 22   QUAL     iShares MSCI USA Quality Factor ETF   0.060733
# 16    IWD          iShares Russell 1000 Value ETF   0.063779
# 42   SPYV        SPDR Portfolio S&P 500 Value ETF   0.064982
